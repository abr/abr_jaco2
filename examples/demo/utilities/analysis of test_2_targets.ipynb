# %%
# %matplotlib inline
import pylab
import pytry
import numpy as np

# %%
data = pytry.read('data')

# %%
print('running')
d = data[-1]
print(d.keys())
# Out:
# running
# dict_keys(['dt', 'xyzs', 'seed', 'error_list', 'nan', 'smooth', 'iterations', 'total_error', 'training_signal_list', 'T'])

# %%
pylab.plot(d['total_error'][::2])
pylab.plot(d['total_error'][1::2])

# %%
for i, errors in enumerate(d['error_list']):
    pylab.plot(errors)

# %%
xyz = np.array([[float(v) for v in row[1:-1].split()] for row in d['xyzs']])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-576e50c7e8be> in <module>()
# ----> 1 xyz = np.array([[float(v) for v in row[1:-1].split()] for row in d['xyzs']])
#
# <ipython-input-6-576e50c7e8be> in <listcomp>(.0)
# ----> 1 xyz = np.array([[float(v) for v in row[1:-1].split()] for row in d['xyzs']])
#
# AttributeError: 'list' object has no attribute 'split'

# %%
pylab.plot(xyz[:,0], xyz[:,2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fb0e2ae2e41e> in <module>()
# ----> 1 pylab.plot(xyz[:,0], xyz[:,2])
#
# NameError: name 'xyz' is not defined

# %%
pylab.plot(np.vstack(d['training_signal_list']))
